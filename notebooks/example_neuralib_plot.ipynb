# %% [markdown]
# # Example usage of `neuralib.plot`

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from neuralib.plot import (
    plot_half_violin_box_dot, 
    plot_joint_scatter_histogram,
    plot_regression_cc,
    plot_2d_dots,
    VennHandler,
    plot_venn
)

# %%
# %load_ext autoreload
# %autoreload

# %%
# load example data
iris = sns.load_dataset('iris')
x = hue = 'species'
y = 'sepal_length'

# %% [markdown]
# ### Plot the data with half violin together with boxes and dots

# %%
fig, ax = plt.subplots()
plot_half_violin_box_dot(data=iris, x=x, y=y, hue=hue, ax=ax)
plt.show()

# %% [markdown]
# ### See correlation and histogram of two variables

# %%
x = iris['petal_width']
y = iris['sepal_width']
plot_joint_scatter_histogram(x, y)

# %% [markdown]
# ### See y as a function of x
# - dotted line indicates the binned **median** or **mean** y values

# %%
fig, ax = plt.subplots()
plot_regression_cc(ax=ax, x=x, y=y, bins=10, bin_func='median')

# %% [markdown]
# ### Plot the 2D dotted

# %%
fig, ax = plt.subplots()

# (X,): different animals
x = ['animal_A', 'animal_B']

# (Y,): subregion in Visual Cortex as an example
y = ['VISam', 'VISp', 'VISpm', 'VISpor', 'VISl', 'VISal', 'VISli', 'VISpl']

# size of the dots (Y, X)
size = np.array([
    [35.33418476, 22.90336313, 16.85823755, 13.40996169,  3.53341848, 5.57684121,  1.8305662 ,  0.55342699],
    [25.14484357, 27.5202781 , 26.36152955,  7.24217845,  5.79374276, 1.76709154,  3.47624565,  2.69409038]
])

plot_2d_dots(ax=ax, x=x, y=y, size=size, size_factor=10, size_type='area')

# %% [markdown]
# ### Plot Venn
# - fraction show pure percentage in **a, overlap, and b**, respectively.

# %%
venn = VennHandler(subset_a=10, subset_b=20, subset_overlap=5, total_set=50)

fig, ax = plt.subplots()
plot_venn(ax, vhandler=venn, labels=['a', 'b'])
